# %% [markdown]
# <a href="https://colab.research.google.com/github/prashantchandel555/function_felabella/blob/main/chapter_appendix-tools-for-deep-learning/jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Variables and dataType of pythons

# %%
a = 10.7
b = 10
c = True
d = "prashant"
e = [1,2,3]
f = (1,2,3)
g = {1,2,3}
h = {"a":10,"b":20}
i = 10+1j
print(type(a),type(b),type(c),type(d),type(e),type(f),type(g),type(h),type(i))
print(e[0],f[0],list(g)[0],h["a"])
# Out:
# <class 'float'> <class 'int'> <class 'bool'> <class 'str'> <class 'list'> <class 'tuple'> <class 'set'> <class 'dict'> <class 'complex'>
# 1 1 1 10

# %% [markdown]
# #Artmatic operator

# %%
a = 10.3
b = 20

print (a+b,a-b,a*b,a/b,a//b,a%b,a**b)
# Out:
# 30.3 -9.7 206.0 0.515 0.0 10.3 1.8061112346694163e+20

# %% [markdown]
# #logical operator

# %%
a = True
b = False
print(a and  b, a or b, not a, not b)
# Out:
# False True False True

# %% [markdown]
# #Relational Operator

# %%
a = 2
b = 5
print(a>b,a<b,a==b,a>=b,a<=b,a!=b)
# Out:
# False True False False True True

# %% [markdown]
# #Assingnment Operator

# %%
a = 5
print(a)
a += 5
a = 5
print(a)
a -= 5
a = 5
print(a)
a *= 5
a = 5
print(a)
a %= 5
print(a)
a = 5
a //= 5
print(a)
a = 5
a /= 5
print(a)
a = 5
a **= 5
print(a)
# Out:
# 5
# 5
# 5
# 5
# 0
# 1
# 1.0
# 3125
